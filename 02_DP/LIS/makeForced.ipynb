# %%
import random

def generar_permutacion_aleatoria(elementos, semilla=None):
    if semilla is not None:
        random.seed(semilla)
    
    return random.sample(elementos, len(elementos))

# %%
numeros = list(range(1,1001))
with open("Test/f01.in", "w") as f:
    f.write(f"{len(numeros)}\n")
    f.write(" ".join(map(str, numeros)) + "\n")

# %%
numeros.reverse()
with open("Test/f02.in", "w") as f:
    f.write(f"{len(numeros)}\n")
    f.write(" ".join(map(str, numeros)) + "\n")

# %%
numeros[998], numeros[999] = numeros[999], numeros[998]
with open("Test/f03.in", "w") as f:
    f.write(f"{len(numeros)}\n")
    f.write(" ".join(map(str, numeros)) + "\n")

# %%
numeros.reverse()
with open("Test/f04.in", "w") as f:
    f.write(f"{len(numeros)}\n")
    f.write(" ".join(map(str, numeros)) + "\n")
